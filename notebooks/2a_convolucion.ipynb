# %% [markdown]
# <a href="https://colab.research.google.com/github/gibranfp/CursoAprendizajeProfundo/blob/2027-1/notebooks/2a_convolucion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Correlaciones cruzadas y convoluciones
# En esta libreta implementaremos la operación de correlación cruzada, que es la que emplean las capas convolucionales, usando tensores de PyTorch y la compararemos con las operaciones de convolución y correlación cruzada implementadas en la biblioteca SciPy.

# %%
from math import floor
import matplotlib.pyplot as plt
import numpy as np
import torch as th


from scipy.signal import correlate2d, convolve2d
from sklearn.datasets import load_digits

# %% [markdown]
# ## Carga conjunto de datos de dígitos
# Descargamos el conjunto de datos de dígitos de la biblioteca `scikit-learn`.

# %%
digits = load_digits()
data = digits.images
labels = digits.target

# %% [markdown]
# Desplegamos el contenido de una imagen.

# %%
print(f'Imagen original:\n {data[0]}')

# %% [markdown]
# Este conjunto de datos está compuesto por imágenes de $8 \times 8$ en escala de grises de los dígitos $0-9$, con valores enteros entre 0 y 16.
#
# Normalizamos los valores de las imágenes para que queden en el intervalo $[0,1]$.

# %%
data = data / data.max()

print(f'Imagen normalizada:\n {data[0]}')

# %% [markdown]
# Visualizamos 2 instancias de los dígitos $0$ y $1$:

# %%
imagen0 = data[labels == 0][0]
imagen1 = data[labels == 1][0]

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(imagen0, cmap = 'gray')
axs[0].set_title('Ejemplo de dígito 0')

axs[1].imshow(imagen1, cmap = 'gray')
axs[1].set_title('Ejemplo de dígito 1')
plt.show()

# %% [markdown]
# ## Convolución y correlación cruzada
# Ahora consideremos la operación de convolución entre una imagen $\mathbf{I}$ y un filtro $\mathbf{K}$, la cual está definida por
# $$
# (\mathbf{I} * \mathbf{K})[i,j] = \sum_m \sum_n I[m,n]\, K[i-m,\,j-n].
# $$
#
# La convolución es conmutativa, por lo tanto
# $$
# (\mathbf{K} * \mathbf{I})[i,j] = \sum_m \sum_n I[i-m,\,j-n]\, K[m,n].
# $$
#
# En lugar de la convolución, frecuentemente se emplea la operación de correlación cruzada para llevar a cabo las capas convolucionales. Esta operación es similar a la convolución pero sin voltear el filtro (por lo que pierde la propiedad de conmutatividad) y está dada por
# $$
# (\mathbf{I} \star \mathbf{K})[i,j] = \sum_m \sum_n I[i+m,\,j+n]\, K[m,n].
# $$
#
# Agregando el sesgo $b$ obtenemos el mapa
# $$
# Z[i,j] = (\mathbf{I} \star \mathbf{K})[i,j] + b,
# $$
#
# al que le aplicamos una función de activación para obtener el mapa de características o activaciones $\mathbf{A}$.
#
# Implementamos la correlación cruzada con tensores de PyTorch en una función. Siguiendo la convención de las bibliotecas de aprendizaje profundo, la llamamos `conv2d`, a pesar de que no es una convolución.

# %%
def conv2d(I, K, b, stride = 1):
  # Calculamos el alto y ancho de la salida
  h_s = int(floor((I.shape[0] - K.shape[0]) / stride)) + 1
  w_s = int(floor((I.shape[1] - K.shape[1]) / stride)) + 1

  Z = th.zeros((h_s, w_s), dtype = I.dtype)
  for i in range(h_s):
    for j in range(w_s):
      I_m = I[i * stride:i * stride + K.shape[0], j * stride:j * stride + K.shape[1]]
      Z[i, j] = (I_m * K).sum() + b

  return Z

# %% [markdown]
# ## Filtro
#
# Creamos un filtro de $3 \times 3$ que detecte bordes en cierta orientación.

# %%
filtro1 = np.eye(3)
plt.imshow(filtro1 * 0.5 + 0.5, cmap = 'gray')
plt.show()

# %% [markdown]
# Realizamos las operaciones de correlación cruzada y convolución de una imagen del dígito 0 con dicho filtro y al revés y aplicamos a cada resultado la función de activación tangente hiperbólico.

# %%
def conv_corr(imagen, filtro):
  corrc1 = np.tanh(correlate2d(imagen, filtro, mode = 'valid'))
  corrc2 = np.tanh(correlate2d(filtro, imagen, mode = 'valid'))
  conv1 = np.tanh(convolve2d(imagen, filtro, mode = 'valid'))
  conv2 = np.tanh(convolve2d(filtro, imagen, mode = 'valid'))

  a_conv2d = th.tanh(conv2d(th.as_tensor(imagen), th.as_tensor(filtro), 0, stride = 1))

  return corrc1, corrc2, conv1, conv2, a_conv2d

corrc1, corrc2, conv1, conv2, a_conv2d = conv_corr(imagen0, filtro1)

fig, axs = plt.subplots(1, 6, figsize=(15, 5))
axs[0].imshow(imagen0, cmap = 'gray')
axs[0].set_title('Imagen original', fontsize=9)

axs[1].imshow(corrc1, cmap = 'gray')
axs[1].set_title(r'Corr. Cruzada ($\mathbf{I}$, $\mathbf{K}$)', fontsize=9)

axs[2].imshow(corrc2, cmap = 'gray')
axs[2].set_title(r'Corr. Cruzada ($\mathbf{K}$, $\mathbf{K}$)', fontsize=9)

axs[3].imshow(conv1, cmap = 'gray')
axs[3].set_title(r'Convolución ($\mathbf{I}$, $\mathbf{K}$)', fontsize=9)

axs[4].imshow(conv2, cmap = 'gray')
axs[4].set_title(r'Convolución ($\mathbf{K}$, $\mathbf{I}$)', fontsize=9)

axs[5].imshow(a_conv2d.numpy(), cmap = 'gray')
axs[5].set_title('Función conv2d', fontsize=9)

plt.show()

# %% [markdown]
# Observa que el resultado de la correlación cruzada de la imagen con el filtro no es igual al del filtro con la imagen: es el mismo mapa rotado 180°, ya que intercambiar los argumentos equivale a invertir el signo de los índices. En contraste, la convolución sí es conmutativa y produce exactamente el mismo resultado en ambos casos.
#
# Repetimos el procedimiento para una imagen del dígito 1:

# %%
corrc1, corrc2, conv1, conv2, a_conv2d = conv_corr(imagen1, filtro1)

fig, axs = plt.subplots(1, 6, figsize=(15, 5))
axs[0].imshow(imagen1, cmap = 'gray')
axs[0].set_title('Imagen original', fontsize=9)

axs[1].imshow(corrc1, cmap = 'gray')
axs[1].set_title(r'Corr. Cruzada ($\mathbf{I}$, $\mathbf{K}$)', fontsize=9)

axs[2].imshow(corrc2, cmap = 'gray')
axs[2].set_title(r'Corr. Cruzada ($\mathbf{K}$, $\mathbf{K}$)', fontsize=9)

axs[3].imshow(conv1, cmap = 'gray')
axs[3].set_title(r'Convolución ($\mathbf{I}$, $\mathbf{K}$)', fontsize=9)

axs[4].imshow(conv2, cmap = 'gray')
axs[4].set_title(r'Convolución ($\mathbf{K}$, $\mathbf{I}$)', fontsize=9)

axs[5].imshow(a_conv2d.numpy(), cmap = 'gray')
axs[5].set_title('Función conv2d', fontsize=9)

plt.show()

# %% [markdown]
# Creamos tres filtros más de $3\times 3$, que junto con el anterior detectan bordes en cuatro orientaciones distintas.

# %%
filtros = np.zeros((4, 3, 3))
filtros[0, :, :] = filtro1
filtros[1, 1, :] = 1
filtros[2, :, 1] = 1
filtros[3, :, :] = filtros[0, ::-1]

b = np.zeros(filtros.shape[0])

nombres = ['Diagonal', 'Horizontal', 'Vertical', 'Antidiagonal']

f, axs = plt.subplots(nrows=1, ncols=4, figsize=(15,5))
for i in range(filtros.shape[0]):
  axs[i].imshow(filtros[i], cmap = 'gray')
  axs[i].set_title(f'{nombres[i]}')

for ax in axs.ravel():
  ax.set_xticks([]); ax.set_yticks([])

plt.show()

# %% [markdown]
# Para aplicar la función `conv2d` a cada uno de estos filtros definimos la siguiente función:

# %%
def multi_conv2d(I, K, b, stride = 1):
  n_filtros = K.shape[0]
  A = []
  for i in range(n_filtros):
    A.append(conv2d(I, K[i], b[i], stride = stride))

  return th.stack(A)

# %% [markdown]
# Evaluamos esta función con cuatro distintos filtros para nuestras dos imágenes, obteniendo cuatro mapas por cada imagen.

# %%
Z_0 = multi_conv2d(th.as_tensor(imagen0), th.as_tensor(filtros), b, stride = 1)
Z_1 = multi_conv2d(th.as_tensor(imagen1), th.as_tensor(filtros), b, stride = 1)
A_0 = th.tanh(Z_0)
A_1 = th.tanh(Z_1)

f, axs = plt.subplots(nrows=3, ncols=4, figsize=(15, 7))
for i in range(filtros.shape[0]):
    axs[0, i].imshow(filtros[i], cmap='gray')
    axs[0, i].set_title(nombres[i], fontsize=9)
    axs[1, i].imshow(A_0[i], cmap='gray')
    axs[2, i].imshow(A_1[i], cmap='gray')

for ax in axs.ravel():
    ax.set_xticks([]); ax.set_yticks([])

for ax, etiqueta in zip(axs[:, 0], ['Filtro', 'Dígito 0', 'Dígito 1']):
    ax.set_ylabel(etiqueta, fontsize=9)

plt.show()

# %% [markdown]
# Ahora definimos funciones para realizar un submuestreo máximo a un conjunto de mapas.

# %%
def submuestreo_maximo(A, bloque = (2, 2)):
  H_s = A.shape[0] // bloque[0]
  W_s = A.shape[1] // bloque[1]

  sub_A = th.zeros((H_s, W_s))
  for i in range(H_s):
    for j in range(W_s):
      region = A[i*bloque[0]:(i+1)*bloque[0], j*bloque[1]:(j+1)*bloque[1]]
      sub_A[i, j] = region.max()
  return sub_A

def multi_submuestreo_maximo(A, bloque = (2,2)):
  n_filtros = A.shape[0]
  sub_A = []
  for i in range(n_filtros):
    sub_A.append(submuestreo_maximo(A[i], bloque = bloque))

  return th.stack(sub_A)

# %% [markdown]
# Aplicamos el submuestreo a nuestros mapas.

# %%
sub_A0 = multi_submuestreo_maximo(A_0, bloque = (2, 2))
sub_A1 = multi_submuestreo_maximo(A_1, bloque = (2, 2))

f, axs = plt.subplots(nrows=3, ncols=4, figsize=(15, 7))
for i in range(filtros.shape[0]):
    axs[0, i].imshow(filtros[i], cmap='gray')
    axs[0, i].set_title(nombres[i], fontsize=9)
    axs[1, i].imshow(sub_A0[i], cmap='gray')
    axs[2, i].imshow(sub_A1[i], cmap='gray')

for ax in axs.ravel():
    ax.set_xticks([]); ax.set_yticks([])

for ax, etiqueta in zip(axs[:, 0], ['Filtro', 'Dígito 0', 'Dígito 1']):
    ax.set_ylabel(etiqueta, fontsize=9)

plt.show()
